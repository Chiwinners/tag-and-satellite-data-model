# %%
# Inspect one ATL24 HDF5 file (depth) from downloads/depth/sample

from pathlib import Path
import os, re, textwrap

# 1) Locate downloads/depth/sample walking up from the current notebook
def find_depth_sample_dir(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    for parent in [start, *start.parents]:
        cand = parent / "downloads" / "depth" / "sample"
        if cand.is_dir():
            return cand
    raise FileNotFoundError(f"Could not find 'downloads/depth/sample' starting from {start}")

sample_dir = find_depth_sample_dir()
files = sorted(list(sample_dir.glob("*.h5")) + list(sample_dir.glob("*.hdf5")))
assert files, f"No .h5/.hdf5 files in {sample_dir}"
h5_path = files[0]  # open the first one (change if you want)

def fmt_size(b):
    for unit in ("B","KB","MB","GB","TB"):
        if b < 1024 or unit == "TB":
            return f"{b:,.1f} {unit}"
        b /= 1024.0

print(f"📂 Folder: {sample_dir}")
print(f"📄 Opening: {h5_path.name}  ({fmt_size(os.path.getsize(h5_path))})\n")

# 2) Try opening with xarray (optional; may fail if it's not netCDF-like)
try:
    import xarray as xr
    tried, last_err, ds = [], None, None
    for eng in ("netcdf4", "h5netcdf", "scipy"):
        try:
            ds = xr.open_dataset(h5_path, engine=eng, decode_cf=False, mask_and_scale=False)
            print(f"✅ xarray.open_dataset succeeded with engine='{eng}'")
            display(ds)
            break
        except Exception as e:
            tried.append(eng); last_err = e
    if ds is None:
        print(f"⚠️ xarray could not open this file with engines {tried}. "
              f"Last error:\n{textwrap.fill(str(last_err), 100)}")
    else:
        try: ds.close()
        except: pass
except Exception as e:
    print("⚠️ xarray not available or failed to import:", e)

# 3) Always show the HDF5 structure with h5py (groups, datasets, shapes, dtypes, root attrs)
import h5py

MAX_ITEMS = 300  # keep output manageable
print("\n🔎 HDF5 tree (groups and datasets):")
with h5py.File(h5_path, "r") as f:
    # Root attributes
    if f.attrs:
        print("\n— Root attributes —")
        for k, v in f.attrs.items():
            v_str = str(v)
            if len(v_str) > 160: v_str = v_str[:157] + "..."
            print(f"  * {k}: {v_str}")

    print("\n— Structure —")
    counter = {"n": 0}  # mutable counter to avoid global/nonlocal

    def visit(name, obj):
        if counter["n"] >= MAX_ITEMS:
            return
        if isinstance(obj, h5py.Dataset):
            print(f"[D] {name}  shape={obj.shape}  dtype={obj.dtype}")
        else:
            print(f"[G] {name}")
        counter["n"] += 1

    f.visititems(visit)

    # Heuristic: highlight datasets with lat/lon/time/depth-like names
    print("\n— Name hints (possible geovars) —")
    pat = re.compile(r"(lat|lon|long|time|depth|elev|x|y)", re.IGNORECASE)
    hints = []
    def collect(name, obj):
        if isinstance(obj, h5py.Dataset) and pat.search(name):
            hints.append((name, obj.shape, str(obj.dtype)))
    f.visititems(collect)
    if hints:
        for n, sh, dt in hints[:40]:
            print(f"  ~ {n}  shape={sh}  dtype={dt}")
        if len(hints) > 40:
            print(f"  ... and {len(hints)-40} more")
    else:
        print("  (no obvious matches)")

print("\nDone.")
# Out:
# 📂 Folder: C:\Users\Crist\Desktop\NASA\tag-and-satellite-data-model\downloads\depth\sample
# 📄 Opening: ATL24_20190614091833_11780301_006_02_001_01.h5  (94.3 MB)
#
# ✅ xarray.open_dataset succeeded with engine='netcdf4'
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*
# 🔎 HDF5 tree (groups and datasets):
#
# — Structure —
# [G] ancillary_data
# [D] ancillary_data/atlas_sdp_gps_epoch  shape=()  dtype=float64
# [D] ancillary_data/data_end_utc  shape=()  dtype=object
# [D] ancillary_data/data_start_utc  shape=()  dtype=object
# [D] ancillary_data/end_cycle  shape=()  dtype=int32
# [D] ancillary_data/end_delta_time  shape=()  dtype=float64
# [D] ancillary_data/end_geoseg  shape=()  dtype=int32
# [D] ancillary_data/end_gpssow  shape=()  dtype=float64
# [D] ancillary_data/end_gpsweek  shape=()  dtype=int32
# [D] ancillary_data/end_orbit  shape=()  dtype=int32
# [D] ancillary_data/end_region  shape=()  dtype=int32
# [D] ancillary_data/end_rgt  shape=()  dtype=int32
# [D] ancillary_data/granule_end_utc  shape=()  dtype=object
# [D] ancillary_data/granule_start_utc  shape=()  dtype=object
# [D] ancillary_data/release  shape=()  dtype=object
# [D] ancillary_data/resource  shape=()  dtype=object
# [D] ancillary_data/sliderule_commit  shape=()  dtype=object
# [D] ancillary_data/sliderule_environment  shape=()  dtype=object
# [D] ancillary_data/sliderule_version  shape=()  dtype=object
# [D] ancillary_data/start_cycle  shape=()  dtype=int32
# [D] ancillary_data/start_delta_time  shape=()  dtype=float64
# [D] ancillary_data/start_geoseg  shape=()  dtype=int32
# [D] ancillary_data/start_gpssow  shape=()  dtype=float64
# [D] ancillary_data/start_gpsweek  shape=()  dtype=int32
# [D] ancillary_data/start_orbit  shape=()  dtype=int32
# [D] ancillary_data/start_region  shape=()  dtype=int32
# [D] ancillary_data/start_rgt  shape=()  dtype=int32
# [D] ancillary_data/version  shape=()  dtype=object
# [G] gt1l
# [D] gt1l/class_ph  shape=(915989,)  dtype=int8
# [D] gt1l/confidence  shape=(915989,)  dtype=float64
# [D] gt1l/delta_time  shape=(915989,)  dtype=float64
# [D] gt1l/ellipse_h  shape=(915989,)  dtype=float32
# [D] gt1l/index_ph  shape=(915989,)  dtype=int32
# [D] gt1l/index_seg  shape=(915989,)  dtype=int32
# [D] gt1l/invalid_kd  shape=(915989,)  dtype=uint8
# [D] gt1l/invalid_wind_speed  shape=(915989,)  dtype=uint8
# [D] gt1l/lat_ph  shape=(915989,)  dtype=float64
# [D] gt1l/lon_ph  shape=(915989,)  dtype=float64
# [D] gt1l/low_confidence_flag  shape=(915989,)  dtype=uint8
# [D] gt1l/night_flag  shape=(915989,)  dtype=uint8
# [D] gt1l/ortho_h  shape=(915989,)  dtype=float32
# [D] gt1l/sensor_depth_exceeded  shape=(915989,)  dtype=uint8
# [D] gt1l/sigma_thu  shape=(915989,)  dtype=float32
# [D] gt1l/sigma_tvu  shape=(915989,)  dtype=float32
# [D] gt1l/surface_h  shape=(915989,)  dtype=float32
# [D] gt1l/x_atc  shape=(915989,)  dtype=float64
# [D] gt1l/y_atc  shape=(915989,)  dtype=float32
# [G] gt1r
# [D] gt1r/class_ph  shape=(168008,)  dtype=int8
# [D] gt1r/confidence  shape=(168008,)  dtype=float64
# [D] gt1r/delta_time  shape=(168008,)  dtype=float64
# [D] gt1r/ellipse_h  shape=(168008,)  dtype=float32
# [D] gt1r/index_ph  shape=(168008,)  dtype=int32
# [D] gt1r/index_seg  shape=(168008,)  dtype=int32
# [D] gt1r/invalid_kd  shape=(168008,)  dtype=uint8
# [D] gt1r/invalid_wind_speed  shape=(168008,)  dtype=uint8
# [D] gt1r/lat_ph  shape=(168008,)  dtype=float64
# [D] gt1r/lon_ph  shape=(168008,)  dtype=float64
# [D] gt1r/low_confidence_flag  shape=(168008,)  dtype=uint8
# [D] gt1r/night_flag  shape=(168008,)  dtype=uint8
# [D] gt1r/ortho_h  shape=(168008,)  dtype=float32
# [D] gt1r/sensor_depth_exceeded  shape=(168008,)  dtype=uint8
# [D] gt1r/sigma_thu  shape=(168008,)  dtype=float32
# [D] gt1r/sigma_tvu  shape=(168008,)  dtype=float32
# [D] gt1r/surface_h  shape=(168008,)  dtype=float32
# [D] gt1r/x_atc  shape=(168008,)  dtype=float64
# [D] gt1r/y_atc  shape=(168008,)  dtype=float32
# [G] gt2l
# [D] gt2l/class_ph  shape=(718724,)  dtype=int8
# [D] gt2l/confidence  shape=(718724,)  dtype=float64
# [D] gt2l/delta_time  shape=(718724,)  dtype=float64
# [D] gt2l/ellipse_h  shape=(718724,)  dtype=float32
# [D] gt2l/index_ph  shape=(718724,)  dtype=int32
# [D] gt2l/index_seg  shape=(718724,)  dtype=int32
# [D] gt2l/invalid_kd  shape=(718724,)  dtype=uint8
# [D] gt2l/invalid_wind_speed  shape=(718724,)  dtype=uint8
# [D] gt2l/lat_ph  shape=(718724,)  dtype=float64
# [D] gt2l/lon_ph  shape=(718724,)  dtype=float64
# [D] gt2l/low_confidence_flag  shape=(718724,)  dtype=uint8
# [D] gt2l/night_flag  shape=(718724,)  dtype=uint8
# [D] gt2l/ortho_h  shape=(718724,)  dtype=float32
# [D] gt2l/sensor_depth_exceeded  shape=(718724,)  dtype=uint8
# [D] gt2l/sigma_thu  shape=(718724,)  dtype=float32
# [D] gt2l/sigma_tvu  shape=(718724,)  dtype=float32
# [D] gt2l/surface_h  shape=(718724,)  dtype=float32
# [D] gt2l/x_atc  shape=(718724,)  dtype=float64
# [D] gt2l/y_atc  shape=(718724,)  dtype=float32
# [G] gt2r
# [D] gt2r/class_ph  shape=(175189,)  dtype=int8
# [D] gt2r/confidence  shape=(175189,)  dtype=float64
# [D] gt2r/delta_time  shape=(175189,)  dtype=float64
# [D] gt2r/ellipse_h  shape=(175189,)  dtype=float32
# [D] gt2r/index_ph  shape=(175189,)  dtype=int32
# [D] gt2r/index_seg  shape=(175189,)  dtype=int32
# [D] gt2r/invalid_kd  shape=(175189,)  dtype=uint8
# [D] gt2r/invalid_wind_speed  shape=(175189,)  dtype=uint8
# [D] gt2r/lat_ph  shape=(175189,)  dtype=float64
# [D] gt2r/lon_ph  shape=(175189,)  dtype=float64
# [D] gt2r/low_confidence_flag  shape=(175189,)  dtype=uint8
# [D] gt2r/night_flag  shape=(175189,)  dtype=uint8
# [D] gt2r/ortho_h  shape=(175189,)  dtype=float32
# [D] gt2r/sensor_depth_exceeded  shape=(175189,)  dtype=uint8
# [D] gt2r/sigma_thu  shape=(175189,)  dtype=float32
# [D] gt2r/sigma_tvu  shape=(175189,)  dtype=float32
# [D] gt2r/surface_h  shape=(175189,)  dtype=float32
# [D] gt2r/x_atc  shape=(175189,)  dtype=float64
# [D] gt2r/y_atc  shape=(175189,)  dtype=float32
# [G] gt3l
# [D] gt3l/class_ph  shape=(989997,)  dtype=int8
# [D] gt3l/confidence  shape=(989997,)  dtype=float64
# [D] gt3l/delta_time  shape=(989997,)  dtype=float64
# [D] gt3l/ellipse_h  shape=(989997,)  dtype=float32
# [D] gt3l/index_ph  shape=(989997,)  dtype=int32
# [D] gt3l/index_seg  shape=(989997,)  dtype=int32
# [D] gt3l/invalid_kd  shape=(989997,)  dtype=uint8
# [D] gt3l/invalid_wind_speed  shape=(989997,)  dtype=uint8
# [D] gt3l/lat_ph  shape=(989997,)  dtype=float64
# [D] gt3l/lon_ph  shape=(989997,)  dtype=float64
# [D] gt3l/low_confidence_flag  shape=(989997,)  dtype=uint8
# [D] gt3l/night_flag  shape=(989997,)  dtype=uint8
# [D] gt3l/ortho_h  shape=(989997,)  dtype=float32
# [D] gt3l/sensor_depth_exceeded  shape=(989997,)  dtype=uint8
# [D] gt3l/sigma_thu  shape=(989997,)  dtype=float32
# [D] gt3l/sigma_tvu  shape=(989997,)  dtype=float32
# [D] gt3l/surface_h  shape=(989997,)  dtype=float32
# [D] gt3l/x_atc  shape=(989997,)  dtype=float64
# [D] gt3l/y_atc  shape=(989997,)  dtype=float32
# [G] gt3r
# [D] gt3r/class_ph  shape=(155870,)  dtype=int8
# [D] gt3r/confidence  shape=(155870,)  dtype=float64
# [D] gt3r/delta_time  shape=(155870,)  dtype=float64
# [D] gt3r/ellipse_h  shape=(155870,)  dtype=float32
# [D] gt3r/index_ph  shape=(155870,)  dtype=int32
# [D] gt3r/index_seg  shape=(155870,)  dtype=int32
# [D] gt3r/invalid_kd  shape=(155870,)  dtype=uint8
# [D] gt3r/invalid_wind_speed  shape=(155870,)  dtype=uint8
# [D] gt3r/lat_ph  shape=(155870,)  dtype=float64
# [D] gt3r/lon_ph  shape=(155870,)  dtype=float64
# [D] gt3r/low_confidence_flag  shape=(155870,)  dtype=uint8
# [D] gt3r/night_flag  shape=(155870,)  dtype=uint8
# [D] gt3r/ortho_h  shape=(155870,)  dtype=float32
# [D] gt3r/sensor_depth_exceeded  shape=(155870,)  dtype=uint8
# [D] gt3r/sigma_thu  shape=(155870,)  dtype=float32
# [D] gt3r/sigma_tvu  shape=(155870,)  dtype=float32
# [D] gt3r/surface_h  shape=(155870,)  dtype=float32
# [D] gt3r/x_atc  shape=(155870,)  dtype=float64
# [D] gt3r/y_atc  shape=(155870,)  dtype=float32
# [G] metadata
# [D] metadata/extent  shape=()  dtype=object
# [D] metadata/profile  shape=()  dtype=object
# [D] metadata/sliderule  shape=()  dtype=object
# [D] metadata/stats  shape=()  dtype=object
# [G] orbit_info
# [D] orbit_info/crossing_time  shape=()  dtype=float64
# [D] orbit_info/cycle_number  shape=()  dtype=int8
# [D] orbit_info/lan  shape=()  dtype=float64
# [D] orbit_info/orbit_number  shape=()  dtype=int16
# [D] orbit_info/rgt  shape=()  dtype=int16
# [D] orbit_info/sc_orient  shape=()  dtype=int8
# [D] orbit_info/sc_orient_time  shape=()  dtype=float64
#
# — Name hints (possible geovars) —
#   ~ ancillary_data/atlas_sdp_gps_epoch  shape=()  dtype=float64
#   ~ ancillary_data/data_end_utc  shape=()  dtype=object
#   ~ ancillary_data/data_start_utc  shape=()  dtype=object
#   ~ ancillary_data/end_cycle  shape=()  dtype=int32
#   ~ ancillary_data/end_delta_time  shape=()  dtype=float64
#   ~ ancillary_data/end_geoseg  shape=()  dtype=int32
#   ~ ancillary_data/end_gpssow  shape=()  dtype=float64
#   ~ ancillary_data/end_gpsweek  shape=()  dtype=int32
#   ~ ancillary_data/end_orbit  shape=()  dtype=int32
#   ~ ancillary_data/end_region  shape=()  dtype=int32
#   ~ ancillary_data/end_rgt  shape=()  dtype=int32
#   ~ ancillary_data/granule_end_utc  shape=()  dtype=object
#   ~ ancillary_data/granule_start_utc  shape=()  dtype=object
#   ~ ancillary_data/release  shape=()  dtype=object
#   ~ ancillary_data/resource  shape=()  dtype=object
#   ~ ancillary_data/sliderule_commit  shape=()  dtype=object
#   ~ ancillary_data/sliderule_environment  shape=()  dtype=object
#   ~ ancillary_data/sliderule_version  shape=()  dtype=object
#   ~ ancillary_data/start_cycle  shape=()  dtype=int32
#   ~ ancillary_data/start_delta_time  shape=()  dtype=float64
#   ~ ancillary_data/start_geoseg  shape=()  dtype=int32
#   ~ ancillary_data/start_gpssow  shape=()  dtype=float64
#   ~ ancillary_data/start_gpsweek  shape=()  dtype=int32
#   ~ ancillary_data/start_orbit  shape=()  dtype=int32
#   ~ ancillary_data/start_region  shape=()  dtype=int32
#   ~ ancillary_data/start_rgt  shape=()  dtype=int32
#   ~ ancillary_data/version  shape=()  dtype=object
#   ~ gt1l/delta_time  shape=(915989,)  dtype=float64
#   ~ gt1l/index_ph  shape=(915989,)  dtype=int32
#   ~ gt1l/index_seg  shape=(915989,)  dtype=int32
#   ~ gt1l/lat_ph  shape=(915989,)  dtype=float64
#   ~ gt1l/lon_ph  shape=(915989,)  dtype=float64
#   ~ gt1l/sensor_depth_exceeded  shape=(915989,)  dtype=uint8
#   ~ gt1l/x_atc  shape=(915989,)  dtype=float64
#   ~ gt1l/y_atc  shape=(915989,)  dtype=float32
#   ~ gt1r/delta_time  shape=(168008,)  dtype=float64
#   ~ gt1r/index_ph  shape=(168008,)  dtype=int32
#   ~ gt1r/index_seg  shape=(168008,)  dtype=int32
#   ~ gt1r/lat_ph  shape=(168008,)  dtype=float64
#   ~ gt1r/lon_ph  shape=(168008,)  dtype=float64
#   ... and 39 more
#
# Done.
